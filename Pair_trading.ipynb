# %% [markdown]
# # 1.Chuẩn bị dữ liệu

# %% [markdown]
# ## 1.1 Tải dữ liệu

# %%
import pandas as pd

# %%
file_name ='data_10y.csv'
data = pd.read_csv(file_name, header=[0, 1], index_col=0, parse_dates=True)

# %%
print(data)
# Out:
# Price              Close                                            \
# Ticker            ACB.VN        BID.VN        CTG.VN        FPT.VN
# Date
# 2015-10-01   3166.126709  13552.242188  13480.748047  10588.070312
# 2015-10-02   3182.446777  13379.234375  13411.968750  10588.070312
# 2015-10-05   3198.767334  13609.911133  13755.865234  10683.030273
# 2015-10-06   3296.688721  14186.602539  13962.203125  10920.430664
# 2015-10-07   3247.728027  13840.588867  13755.865234  10730.510742
# ...                  ...           ...           ...           ...
# 2025-09-25  25650.000000  40450.000000  49895.804688  98000.000000
# 2025-09-26  25650.000000  40103.851562  50292.589844  97500.000000
# 2025-09-29  25600.000000  39856.601562  50590.179688  95500.000000
# 2025-09-30  25500.000000  39559.902344  50391.785156  93000.000000
# 2025-10-01  25800.000000  39609.351562  51086.160156  93400.000000
#
# Price                                                               \
# Ticker            GAS.VN        HPG.VN        MBB.VN        NKG.VN
# Date
# 2015-10-01  31035.990234   3517.593018   3143.698486   3153.011230
# 2015-10-02  30900.164062   3540.509033   3123.016357   3153.011230
# 2015-10-05  31103.900391   3597.798828   3143.698486   3153.011230
# 2015-10-06  31443.464844   3666.546387   3205.745117   3106.300049
# 2015-10-07  32258.416016   3609.256592   3185.063232   3106.300049
# ...                  ...           ...           ...           ...
# 2025-09-25  61900.000000  28800.000000  26550.000000  18450.000000
# 2025-09-26  61500.000000  28550.000000  26250.000000  18300.000000
# 2025-09-29  61500.000000  28600.000000  26150.000000  18150.000000
# 2025-09-30  60400.000000  28150.000000  26200.000000  17600.000000
# 2025-10-01  60600.000000  28300.000000  26400.000000  17650.000000
#
# Price                                   ...      Volume                       \
# Ticker            REE.VN        VCB.VN  ...      ACB.VN   BID.VN      CTG.VN
# Date                                    ...
# 2015-10-01  11765.997070  14035.710938  ...   1270602.0   550497    904126.0
# 2015-10-02  11719.120117  14035.710938  ...    886898.0   990041   1125769.0
# 2015-10-05  11906.627930  14198.916992  ...   1230563.0   856719   1629603.0
# 2015-10-06  12094.133789  14786.458008  ...   5003319.0  3073105   4581641.0
# 2015-10-07  11953.502930  14753.816406  ...   1051284.0  1311715   2379324.0
# ...                  ...           ...  ...         ...      ...         ...
# 2025-09-25  67600.000000  62543.476562  ...   8170967.0  2011804   4726589.0
# 2025-09-26  66300.000000  62543.476562  ...   8983364.0  2298181  10403110.0
# 2025-09-29  65000.000000  62146.375000  ...   8274812.0  2112994   4419731.0
# 2025-09-30  65500.000000  61550.726562  ...  11102950.0  3687433   6645822.0
# 2025-10-01  65800.000000  61947.828125  ...  10969310.0  2221536   7807044.0
#
# Price
# Ticker        FPT.VN   GAS.VN    HPG.VN    MBB.VN    NKG.VN   REE.VN   VCB.VN
# Date
# 2015-10-01   1946017   411748   2653519  13479224     19340  1107693   852290
# 2015-10-02   1137798   336029   7887085   4768455     14846   487430  1258958
# 2015-10-05   1544248   742611  11349481  11742815    254490   658555  1022155
# 2015-10-06   3811457  1289941  27998433  16335971    138887  2580810  4244956
# 2015-10-07   1363392  1544694  17823847   8252098     53381   520556  4643323
# ...              ...      ...       ...       ...       ...      ...      ...
# 2025-09-25   9840162   551081  38598450  17414330  10699170  1339112  4081042
# 2025-09-26   9115898   265966  39386840  13168930  16660260   659878  4027553
# 2025-09-29  11578690   382157  43562340  16407990   8925315   823435  3225923
# 2025-09-30  13961910   900197  56648020  20531240  21036530   646848  4301201
# 2025-10-01   7440061   212385  29971080  11660800   6897728   231134  3230888
#
# [2498 rows x 50 columns]

# %% [markdown]
# # 2.Tiền xử lý và phân tích dữ liệu

# %% [markdown]
# ##2.1 Xử lý dữ liệu thiếu

# %%
df_close = data['Close']

# %%
print(df_close.isna().sum())
print(df_close.info())
# Out:
# Ticker
# ACB.VN    5
# BID.VN    0
# CTG.VN    4
# FPT.VN    0
# GAS.VN    0
# HPG.VN    0
# MBB.VN    0
# NKG.VN    0
# REE.VN    0
# VCB.VN    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2498 entries, 2015-10-01 to 2025-10-01
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ACB.VN  2493 non-null   float64
#  1   BID.VN  2498 non-null   float64
#  2   CTG.VN  2494 non-null   float64
#  3   FPT.VN  2498 non-null   float64
#  4   GAS.VN  2498 non-null   float64
#  5   HPG.VN  2498 non-null   float64
#  6   MBB.VN  2498 non-null   float64
#  7   NKG.VN  2498 non-null   float64
#  8   REE.VN  2498 non-null   float64
#  9   VCB.VN  2498 non-null   float64
# dtypes: float64(10)
# memory usage: 214.7 KB
# None

# %%
df_close[df_close.isna().any(axis=1)]
# Out:
# Ticker            ACB.VN        BID.VN        CTG.VN         FPT.VN  \
# Date
# 2020-12-02           NaN  23932.683594  23213.021484   25394.564453
# 2020-12-03           NaN  23990.351562  23247.412109   25394.564453
# 2020-12-04           NaN  24019.187500  23866.425781   25440.238281
# 2020-12-07           NaN  24797.718750  23866.425781   25440.238281
# 2020-12-08           NaN  24624.712891  23728.867188   25668.607422
# 2024-01-18  17654.455078  38824.285156           NaN   70370.726562
# 2024-08-27  20303.921875  40540.726562           NaN  113184.289062
# 2024-10-30  20843.701172  38987.757812           NaN  116088.640625
# 2024-11-05  20553.048828  38742.550781           NaN  113269.718750
#
# Ticker            GAS.VN        HPG.VN        MBB.VN        NKG.VN  \
# Date
# 2020-12-02  57046.460938  15237.848633   7213.179199   6857.638672
# 2020-12-03  57386.023438  15906.932617   7094.930664   7146.990723
# 2020-12-04  58065.144531  15950.099609   7078.037598   7552.083496
# 2020-12-07  58608.441406  16489.683594   7061.145020   8072.916504
# 2020-12-08  58472.621094  16576.015625   7213.179199   8188.657227
# 2024-01-18  64188.617188  20946.968750  13658.450195  21000.000000
# 2024-08-27  71178.609375  21458.333984  15877.324219  18166.666016
# 2024-10-30  66391.875000  22500.000000  16267.750977  17208.333984
# 2024-11-05  65451.476562  22083.333984  15909.859375  17416.666016
#
# Ticker            REE.VN        VCB.VN
# Date
# 2020-12-02  26037.542969  41201.339844
# 2020-12-03  25444.554688  41201.339844
# 2020-12-04  25336.738281  40143.765625
# 2020-12-07  25282.832031  41025.078125
# 2020-12-08  25067.199219  41025.078125
# 2024-01-18  39710.351562  60494.882812
# 2024-08-27  58720.109375  60760.503906
# 2024-10-30  55638.585938  60893.316406
# 2024-11-05  54440.218750  61490.960938

# %%
df_close = df_close.fillna(method='ffill') #fill bằng ngày hôm trước
print(df_close.isna().sum())
# Out:
# Ticker
# ACB.VN    0
# BID.VN    0
# CTG.VN    0
# FPT.VN    0
# GAS.VN    0
# HPG.VN    0
# MBB.VN    0
# NKG.VN    0
# REE.VN    0
# VCB.VN    0
# dtype: int64
# /tmp/ipython-input-1453029756.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_close = df_close.fillna(method='ffill') #fill bằng ngày hôm trước

# %% [markdown]
# #3.Chiến lược giao dịch

# %% [markdown]
# ##3.1 Giao dịch cặp (Pair Trading)

# %% [markdown]
# ###3.1.1 Tìm cặp cổ phiếu

# %%
import matplotlib.pyplot as plt
df = data['Close']

plt.figure(figsize=(14, 7))
for col in df.columns:
    plt.plot(df.index, df[col], label=col)
plt.title("Close")
plt.legend()
plt.show()

# %% [markdown]
# ### 3.1.2 Kiểm định đồng liên kết

# %%
from statsmodels.tsa.stattools import coint

def find_cointegrated_pairs(data):
    n = data.shape[1]
    score_matrix = np.zeros((n, n))
    pvalue_matrix = np.ones((n, n))
    keys = data.columns
    pairs = []

    print("Đang chạy kiểm định Engle-Granger...")
    for i in range(n):
        for j in range(i+1, n): # Tránh lặp lại và tự so sánh
            s1 = data[keys[i]]
            s2 = data[keys[j]]

            # Kiểm định coint từ statsmodels
            # Hàm này thực hiện cả hồi quy và kiểm định ADF trên phần dư
            result = coint(s1, s2)
            score = result[0]
            pvalue = result[1]

            score_matrix[i, j] = score
            pvalue_matrix[i, j] = pvalue

            if pvalue < 0.05:
                pairs.append((keys[i], keys[j], pvalue))
                print(f"Cặp đồng liên kết tìm thấy: {keys[i]} - {keys[j]} (p-value: {pvalue:.4f})")

    return score_matrix, pvalue_matrix, pairs

# %%
split_point = int(len(df) * 0.8)
df_train = df.iloc[:split_point]
df_test = df.iloc[split_point:]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Chạy trên dữ liệu Log Prices
df_kd = df_train.copy()
df_kd = np.log(df_kd)
scores, pvalues, cointegrated_pairs = find_cointegrated_pairs(df_kd)

# Vẽ Heatmap P-values để dễ quan sát
plt.figure(figsize=(14, 10))
sns.heatmap(pvalues, xticklabels=df.columns, yticklabels=df.columns,
            cmap='RdYlGn_r', mask=(pvalues >= 0.99), annot=True, fmt=".5f")
plt.title("Heatmap P-Values của kiểm định Engle-Granger ")
plt.show()
# Out:
# Đang chạy kiểm định Engle-Granger...
# Cặp đồng liên kết tìm thấy: ACB.VN - BID.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - CTG.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - FPT.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - GAS.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - HPG.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - MBB.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - NKG.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - REE.VN (p-value: 0.0000)
# Cặp đồng liên kết tìm thấy: ACB.VN - VCB.VN (p-value: 0.0000)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# /tmp/ipython-input-2386496492.py:18: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   result = coint(s1, s2)
# Cặp đồng liên kết tìm thấy: BID.VN - VCB.VN (p-value: 0.0034)
# Cặp đồng liên kết tìm thấy: CTG.VN - HPG.VN (p-value: 0.0088)
# Cặp đồng liên kết tìm thấy: CTG.VN - MBB.VN (p-value: 0.0488)

# %%
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import numpy as np

def calc_half_life(spread):
    """Tính half-life theo OU process"""
    spread_lag = spread.shift(1).dropna()
    spread_ret = spread.diff().dropna()

    model = sm.OLS(spread_ret, sm.add_constant(spread_lag)).fit()
    beta = model.params.iloc[1]

    if beta >= 0:   # tránh log dương hoặc zero gây lỗi
        return np.inf

    halflife = -np.log(2) / beta
    return halflife


def hurst_exponent(ts):
    """Tính Hurst exponent"""
    lags = range(2, 100)
    tau = [np.sqrt(np.std(np.subtract(ts[lag:], ts[:-lag]))) for lag in lags]
    poly = np.polyfit(np.log(lags), np.log(tau), 1)
    hurst = poly[0] * 2.0
    return hurst


# ============================================================
# KIỂM ĐỊNH TOÀN BỘ CÁC CẶP
# ============================================================

for s1, s2, p in cointegrated_pairs:
    print(f"\n=== Kiểm định cho spread {s1} - {s2} ===")

    y = df[s1]
    x = df[s2]

    # Loại bỏ NaN
    valid_idx = y.notna() & x.notna()
    y = y[valid_idx]
    x = x[valid_idx]

    # OLS để lấy residual (spread)
    X = sm.add_constant(x)
    model = sm.OLS(y, X).fit()
    resid = model.resid

    # ---- ADF TEST ----
    adf_stat, adf_pvalue, _, _, crit, _ = adfuller(resid)
    if adf_pvalue <= 0.05:
      print(f"ADF Statistic : {adf_stat:.4f}")
      print(f"ADF p-value   : {adf_pvalue:.4f}")
      print(f"Critical Values: {crit}")

      # ---- HALF-LIFE ----
      hl = calc_half_life(resid)
      print(f"Half-life     : {hl:.2f}")

      # ---- HURST EXPONENT ----
      hurst = hurst_exponent(resid.values)
      print(f"Hurst Exponent: {hurst:.4f}")
    else:
      print(f'Thất bại')
# Out:
# === Kiểm định cho spread ACB.VN - BID.VN ===
# Thất bại
#
# === Kiểm định cho spread ACB.VN - CTG.VN ===
# ADF Statistic : -3.2322
# ADF p-value   : 0.0182
# Critical Values: {'1%': np.float64(-3.4330077865854363), '5%': np.float64(-2.8627141882428515), '10%': np.float64(-2.5673950671859886)}
# Half-life     : 56.88
# Hurst Exponent: 0.4026
#
# === Kiểm định cho spread ACB.VN - FPT.VN ===
# Thất bại
#
# === Kiểm định cho spread ACB.VN - GAS.VN ===
# Thất bại
#
# === Kiểm định cho spread ACB.VN - HPG.VN ===
# Thất bại
#
# === Kiểm định cho spread ACB.VN - MBB.VN ===
# Thất bại
#
# === Kiểm định cho spread ACB.VN - NKG.VN ===
# Thất bại
#
# === Kiểm định cho spread ACB.VN - REE.VN ===
# ADF Statistic : -3.2700
# ADF p-value   : 0.0163
# Critical Values: {'1%': np.float64(-3.433005627914427), '5%': np.float64(-2.862713234984453), '10%': np.float64(-2.567394559656695)}
# Half-life     : 78.79
# Hurst Exponent: 0.4593
#
# === Kiểm định cho spread ACB.VN - VCB.VN ===
# Thất bại
#
# === Kiểm định cho spread BID.VN - VCB.VN ===
# ADF Statistic : -4.6613
# ADF p-value   : 0.0001
# Critical Values: {'1%': np.float64(-3.4329895489772104), '5%': np.float64(-2.8627061345839557), '10%': np.float64(-2.5673907792989072)}
# Half-life     : 30.17
# Hurst Exponent: 0.4100
#
# === Kiểm định cho spread CTG.VN - HPG.VN ===
# Thất bại
#
# === Kiểm định cho spread CTG.VN - MBB.VN ===
# ADF Statistic : -4.1192
# ADF p-value   : 0.0009
# Critical Values: {'1%': np.float64(-3.4330013210750745), '5%': np.float64(-2.8627113331035243), '10%': np.float64(-2.567393547066656)}
# Half-life     : 57.94
# Hurst Exponent: 0.4295

# %% [markdown]
# ###3.1.3 Chọn cặp

# %%
# Vẽ biểu đồ để hình dung xu hướng giá tích lũy: chọn cặp BID và VCB, lý do cùng nhóm cluster, kiểm định engle,adf và cùng nhóm ngành liên quan đến năng lượng
plt.figure(figsize=(14, 7))

plt.plot(df_close.index, df_close['BID.VN'], label='BID.VN')
plt.plot(df_close.index, df_close['VCB.VN'], label='VCB.VN')
plt.title("Reconstructed Log Prices (Cumulative Log Returns)")
plt.legend()
plt.show()

# %% [markdown]
# ###3.1.4 Tính toán tham số mô hình

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Cài đặt ban đầu
WINDOW = 60  # rolling window
col1, col2 = 'BID.VN','VCB.VN'

df = pd.DataFrame({
    col1: data['Close'][col1],
    col2: data['Close'][col2]
})

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

def pair_trading_signals(df, col1, col2, window=30, entry_z=1.0, exit_z=0.0):
    """
    df: DataFrame có 2 cổ phiếu col1 và col2
    window: rolling window để tính beta/mu
    entry_z: |z| vượt mức này sẽ mở vị thế
    exit_z: |z| nhỏ hơn mức này sẽ đóng vị thế
    atr_window: window để tính ATR của spread
    """
    df = df.copy()

    # --- Log price series ---
    log1 = np.log(df[col1])
    log2 = np.log(df[col2])

    betas = [np.nan]*len(df)
    mus = [np.nan]*len(df)

    # --- Rolling OLS ---
    for i in range(window, len(df)):
        y = log1.iloc[i-window:i]
        x = log2.iloc[i-window:i]

        if y.isna().any() or x.isna().any():
            continue

        X = sm.add_constant(x)
        model = sm.OLS(y, X).fit()

        mus[i] = model.params.iloc[0]   # intercept
        betas[i] = model.params.iloc[1] # slope

    # --- Gán beta/mu về df ---
    df['beta'] = pd.Series(betas, index=df.index)
    df['mu'] = pd.Series(mus, index=df.index)

    # --- Tính spread ---
    df['spread'] = log1 - df['beta'] * log2 - df['mu']

    # --- Tính z-score ---
    df['spread_mean'] = df['spread'].rolling(window).mean()
    df['spread_std'] = df['spread'].rolling(window).std()
    df['zscore'] = (df['spread'] - df['spread_mean']) / df['spread_std']

    # --- Var ---
    df['spread_vol'] = df['spread'].rolling(window=window).std()

    # --- Tạo signal ---
    '''df['signal'] = 0
    df.loc[df['zscore'] > entry_z, 'signal'] = -1   # short spread: bán col1, mua col2
    df.loc[df['zscore'] < -entry_z, 'signal'] = 1   # long spread: mua col1, bán col2'''

    # Optional: thoát vị thế khi |z| < exit_z
    """df.loc[df['zscore'].abs() < exit_z, 'signal'] = 0"""
    return df

# %%
df = pair_trading_signals(df, col1, col2, window=WINDOW)
df
# Out:
#                   BID.VN        VCB.VN      beta        mu    spread  \
# Date
# 2015-10-01  13552.242188  14035.710938       NaN       NaN       NaN
# 2015-10-02  13379.234375  14035.710938       NaN       NaN       NaN
# 2015-10-05  13609.911133  14198.916992       NaN       NaN       NaN
# 2015-10-06  14186.602539  14786.458008       NaN       NaN       NaN
# 2015-10-07  13840.588867  14753.816406       NaN       NaN       NaN
# ...                  ...           ...       ...       ...       ...
# 2025-09-25  40450.000000  62543.476562  1.026085 -0.749854  0.025982
# 2025-09-26  40103.851562  62543.476562  1.022762 -0.712648  0.016888
# 2025-09-29  39856.601562  62146.375000  1.016346 -0.641395  0.016772
# 2025-09-30  39559.902344  61550.726562  1.005627 -0.522550  0.018456
# 2025-10-01  39609.351562  61947.828125  0.989014 -0.338509  0.012499
#
#             spread_mean  spread_std    zscore  spread_vol
# Date
# 2015-10-01          NaN         NaN       NaN         NaN
# 2015-10-02          NaN         NaN       NaN         NaN
# 2015-10-05          NaN         NaN       NaN         NaN
# 2015-10-06          NaN         NaN       NaN         NaN
# 2015-10-07          NaN         NaN       NaN         NaN
# ...                 ...         ...       ...         ...
# 2025-09-25     0.011159    0.020927  0.708308    0.020927
# 2025-09-26     0.011259    0.020940  0.268807    0.020940
# 2025-09-29     0.011408    0.020947  0.256064    0.020947
# 2025-09-30     0.011597    0.020959  0.327237    0.020959
# 2025-10-01     0.011434    0.020912  0.050937    0.020912
#
# [2498 rows x 9 columns]

# %%
import pandas as pd
import numpy as np

def backtest_pair_safe_fixed_shift(
    df,
    col1="BID.VN",
    col2="VCB.VN",
    beta_col="beta",
    zscore_col="zscore",
    spread_vol="spread_vol",
    entry_z=1.0,
    exit_z=0.0,
    max_risk_per_trade=0.02,
    initial_cash=100_000_000,
    buy_fee=0.001,
    sell_fee=0.002,
    allow_short=False,
    stop_loss_pct=0.05,
    vol_lower=0.0005,
    vol_upper=0.02
):

    df = df.copy()

    # SHIFT beta, zscore, volatility
    df[beta_col] = df[beta_col].shift(1)
    df[zscore_col] = df[zscore_col].shift(1)
    df[spread_vol] = df[spread_vol].shift(1)

    cash = initial_cash
    pos1 = 0
    pos2 = 0
    prev_equity = initial_cash
    total_trades = 0

    # initialize output columns
    df["hold1"] = 0
    df["hold2"] = 0
    df["cash"] = 0.0
    df["equity"] = 0.0
    df["daily_pnl"] = 0.0
    df["trades"] = 0

    for i in range(len(df)):
        price1 = float(df.iloc[i][col1])
        price2 = float(df.iloc[i][col2])
        beta = df.iloc[i][beta_col]
        z = df.iloc[i][zscore_col]

        # Skip missing values
        if pd.isna(beta) or pd.isna(z):
            df.iloc[i, df.columns.get_loc("hold1")] = pos1
            df.iloc[i, df.columns.get_loc("hold2")] = pos2
            df.iloc[i, df.columns.get_loc("cash")] = cash
            df.iloc[i, df.columns.get_loc("equity")] = cash + pos1 * price1 + pos2 * price2
            df.iloc[i, df.columns.get_loc("daily_pnl")] = 0.0
            df.iloc[i, df.columns.get_loc("trades")] = 0
            continue

        nav = cash + pos1 * price1 + pos2 * price2
        trades_today = 0

        # Position sizing
        max_leg_value = nav * max_risk_per_trade
        qty1 = int(max_leg_value / (price1 + abs(beta) * price2))
        qty2 = int(qty1 * abs(beta))

        # volatility constraint
        vol_upper = df[spread_vol].quantile(0.95)
        vol_allow = df.iloc[i][spread_vol] > vol_lower and df.iloc[i][spread_vol] < vol_upper

        # ENTRY - High spread → short 1, long 2
        if z > entry_z and vol_allow:

            if allow_short:
                sell_qty1 = qty1
            else:
                sell_qty1 = min(qty1, pos1)

            buy_qty2 = qty2

            net_cash_needed = buy_qty2*price2*(1+buy_fee) - sell_qty1*price1*(1-sell_fee)
            if net_cash_needed > cash:
                factor = cash / net_cash_needed if net_cash_needed > 0 else 0
                buy_qty2 = int(buy_qty2*factor)
                sell_qty1 = int(sell_qty1*factor)

            if allow_short or pos1 >= sell_qty1:
                cash += sell_qty1*price1*(1-sell_fee)
                pos1 -= sell_qty1
                cash -= buy_qty2*price2*(1+buy_fee)
                pos2 += buy_qty2
                trades_today += 1

        # ENTRY - Low spread → long 1, short 2
        elif z < -entry_z and vol_allow:

            buy_qty1 = qty1

            if allow_short:
                sell_qty2 = qty2
            else:
                sell_qty2 = min(qty2, pos2)

            net_cash_needed = buy_qty1*price1*(1+buy_fee) - sell_qty2*price2*(1-sell_fee)
            if net_cash_needed > cash:
                factor = cash / net_cash_needed if net_cash_needed > 0 else 0
                buy_qty1 = int(buy_qty1*factor)
                sell_qty2 = int(sell_qty2*factor)

            if allow_short or pos2 >= sell_qty2:
                cash -= buy_qty1*price1*(1+buy_fee)
                pos1 += buy_qty1
                cash += sell_qty2*price2*(1-sell_fee)
                pos2 -= sell_qty2
                trades_today += 1

        # EXIT logic
        if abs(z) < exit_z:

            if pos1 != 0:
                close_qty1 = min(abs(pos1), qty1)
                close_qty2 = min(abs(pos2), int(close_qty1 * abs(beta)))

                if pos1 > 0:
                    cash += close_qty1*price1*(1-sell_fee)
                    pos1 -= close_qty1
                else:
                    cash -= close_qty1*price1*(1+buy_fee)
                    pos1 += close_qty1

                if pos2 > 0:
                    cash += close_qty2*price2*(1-sell_fee)
                    pos2 -= close_qty2
                else:
                    cash -= close_qty2*price2*(1+buy_fee)
                    pos2 += close_qty2

                trades_today += 1

        # Mark-to-market
        equity = cash + pos1*price1 + pos2*price2
        daily_pnl = equity - prev_equity
        prev_equity = equity

        df.iloc[i, df.columns.get_loc("hold1")] = pos1
        df.iloc[i, df.columns.get_loc("hold2")] = pos2
        df.iloc[i, df.columns.get_loc("cash")] = cash
        df.iloc[i, df.columns.get_loc("equity")] = equity
        df.iloc[i, df.columns.get_loc("daily_pnl")] = daily_pnl
        df.iloc[i, df.columns.get_loc("trades")] = trades_today

        total_trades += trades_today

    # ====================================================================
    # 📌 THÊM TÍNH TOÁN HIỆU SUẤT
    # ====================================================================
    df["return"] = df["equity"].pct_change()

    total_return = df["equity"].iloc[-1] / initial_cash - 1
    n_days = df["return"].count()

    if n_days > 0:
        cagr = (1 + total_return) ** (252 / n_days) - 1
        volatility = df["return"].std() * np.sqrt(252)
        sharpe = cagr / volatility if volatility != 0 else np.nan
    else:
        cagr = volatility = sharpe = np.nan

    performance = {
        "Final Equity": df["equity"].iloc[-1],
        "Net P/L": df["equity"].iloc[-1] - initial_cash,
        "Total Return (%)": round(total_return * 100, 2),
        "CAGR (%)": round(cagr * 100, 2),
        "Volatility (%)": round(volatility * 100, 2),
        "Sharpe Ratio": round(sharpe, 3),
        "Total Trades": total_trades
    }

    print(performance)

    return df, performance

# %%
df_bt, performance = backtest_pair_safe_fixed_shift(
    df,
    col1="BID.VN",
    col2="VCB.VN",
    beta_col="beta",
    zscore_col="zscore",
    entry_z=1,
    exit_z=0.0,
    max_risk_per_trade=0.01,  # 1% NAV mỗi bước
    initial_cash=100_000_000,
    allow_short=False
)

# Bây giờ df_bt là DataFrame → xem kết quả cuối
df_bt[['hold1','hold2','cash','equity','daily_pnl','trades']].tail(10)

# Xem performance summary
performance
# Out:
# {'Final Equity': np.float64(174574657.65871394), 'Net P/L': np.float64(74574657.65871394), 'Total Return (%)': np.float64(74.57), 'CAGR (%)': np.float64(5.78), 'Volatility (%)': np.float64(9.39), 'Sharpe Ratio': np.float64(0.616), 'Total Trades': 1008}
# {'Final Equity': np.float64(174574657.65871394),
#  'Net P/L': np.float64(74574657.65871394),
#  'Total Return (%)': np.float64(74.57),
#  'CAGR (%)': np.float64(5.78),
#  'Volatility (%)': np.float64(9.39),
#  'Sharpe Ratio': np.float64(0.616),
#  'Total Trades': 1008}

# %%
plt.figure(figsize=(14, 7))
plt.plot(df_bt.index, df_bt['equity'], label='Equity')

plt.title("Equity Curve")
plt.legend()
plt.show()

# %% [markdown]
# ###3.1.5 Tối ưu tham số

# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-3.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting colorama>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->bayesian-optimization) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->bayesian-optimization) (3.6.0)
# Downloading bayesian_optimization-3.1.0-py3-none-any.whl (36 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-3.1.0 colorama-0.4.6

# %%
def make_objective_pnl(df, col1, col2,
                       initial_cash=100_000_000,
                       max_risk_per_trade=0.02,
                       buy_fee=0.001, sell_fee=0.002,
                       allow_short=False):

    def _objective(window, entry_z, exit_z):
        window_i = int(round(window))
        window_i = max(window_i, 5)

        entry_z_f = float(entry_z)
        exit_z_f  = float(exit_z)

        df_sig = pair_trading_signals(
            df,
            col1=col1,
            col2=col2,
            window=window_i,
            entry_z=entry_z_f,
            exit_z=exit_z_f
        )

        df_bt, perf = backtest_pair_safe_fixed_shift(
            df_sig,
            col1=col1,
            col2=col2,
            beta_col="beta",
            zscore_col="zscore",
            entry_z=entry_z_f,
            exit_z=exit_z_f,
            max_risk_per_trade=max_risk_per_trade,
            initial_cash=initial_cash,
            buy_fee=buy_fee,
            sell_fee=sell_fee,
            allow_short=allow_short
        )

        final_equity = perf["Final Equity"]
        pnl = final_equity - initial_cash

        print(f"[PNL] win={window_i}, entry={entry_z_f:.3f}, exit={exit_z_f:.3f} -> pnl={pnl:,.0f}")

        return pnl

    return _objective

# %%
from bayes_opt import BayesianOptimization

def optimize_pnl(df, col1, col2):
    # tạo objective
    obj = make_objective_pnl(df, col1, col2)

    # phạm vi tham số
    pbounds = {
        "window": (5, 60),
        "entry_z": (0.5, 3.5),
        "exit_z": (0.2, 0.5) # không được chỉnh về 0
    }

    optimizer = BayesianOptimization(
        f=obj,
        pbounds=pbounds,
        verbose=2,
        random_state=42
    )

    optimizer.maximize(init_points=10, n_iter=50)

    return optimizer

# %% [markdown]
# ### 3.1.6 Backtest (train/test)

# %%
split_point = int(len(df) * 0.8) #df phải tính chỉ số r
df_train = df.iloc[:split_point]
df_test = df.iloc[split_point:]

# %%
opt = optimize_pnl(df_train, "BID.VN", "VCB.VN")
# Out:
# |   iter    |  target   |  window   |  entry_z  |  exit_z   |
# -------------------------------------------------------------
# {'Final Equity': np.float64(103407072.59191212), 'Net P/L': np.float64(3407072.5919121206), 'Total Return (%)': np.float64(3.41), 'CAGR (%)': np.float64(0.42), 'Volatility (%)': np.float64(0.59), 'Sharpe Ratio': np.float64(0.72), 'Total Trades': 8}
# [PNL] win=26, entry=3.352, exit=0.420 -> pnl=3,407,073
# | 1         | 3407072.5 | 25.599706 | 3.3521429 | 0.4195981 |
# {'Final Equity': np.float64(118847932.85184571), 'Net P/L': np.float64(18847932.85184571), 'Total Return (%)': np.float64(18.85), 'CAGR (%)': np.float64(2.2), 'Volatility (%)': np.float64(5.03), 'Sharpe Ratio': np.float64(0.438), 'Total Trades': 990}
# [PNL] win=38, entry=0.968, exit=0.247 -> pnl=18,847,933
# | 2         | 1.884e+07 | 37.926216 | 0.9680559 | 0.2467983 |
# {'Final Equity': np.float64(100000000.0), 'Net P/L': np.float64(0.0), 'Total Return (%)': np.float64(0.0), 'CAGR (%)': np.float64(0.0), 'Volatility (%)': np.float64(0.0), 'Sharpe Ratio': nan, 'Total Trades': 0}
# [PNL] win=8, entry=3.099, exit=0.380 -> pnl=0
# | 3         | 0.0       | 8.1945986 | 3.0985284 | 0.3803345 |
# {'Final Equity': np.float64(121432744.5393526), 'Net P/L': np.float64(21432744.539352596), 'Total Return (%)': np.float64(21.43), 'CAGR (%)': np.float64(2.48), 'Volatility (%)': np.float64(6.49), 'Sharpe Ratio': np.float64(0.382), 'Total Trades': 1569}
# [PNL] win=44, entry=0.562, exit=0.491 -> pnl=21,432,745
# | 4         | 2.143e+07 | 43.943991 | 0.5617534 | 0.4909729 |
# {'Final Equity': np.float64(118615753.27300583), 'Net P/L': np.float64(18615753.27300583), 'Total Return (%)': np.float64(18.62), 'CAGR (%)': np.float64(2.18), 'Volatility (%)': np.float64(6.01), 'Sharpe Ratio': np.float64(0.362), 'Total Trades': 798}
# [PNL] win=51, entry=1.137, exit=0.255 -> pnl=18,615,753
# | 5         | 1.861e+07 | 50.784345 | 1.1370173 | 0.2545474 |
# {'Final Equity': np.float64(98114023.3886944), 'Net P/L': np.float64(-1885976.6113055944), 'Total Return (%)': np.float64(-1.89), 'CAGR (%)': np.float64(-0.24), 'Volatility (%)': np.float64(1.5), 'Sharpe Ratio': np.float64(-0.16), 'Total Trades': 585}
# [PNL] win=15, entry=1.413, exit=0.357 -> pnl=-1,885,977
# | 6         | -1885976. | 15.087248 | 1.4127267 | 0.3574269 |
# {'Final Equity': np.float64(112003737.3256659), 'Net P/L': np.float64(12003737.325665906), 'Total Return (%)': np.float64(12.0), 'CAGR (%)': np.float64(1.44), 'Volatility (%)': np.float64(3.01), 'Sharpe Ratio': np.float64(0.479), 'Total Trades': 664}
# [PNL] win=29, entry=1.374, exit=0.384 -> pnl=12,003,737
# | 7         | 1.200e+07 | 28.756976 | 1.3736874 | 0.3835558 |
# {'Final Equity': np.float64(103902756.73052952), 'Net P/L': np.float64(3902756.730529517), 'Total Return (%)': np.float64(3.9), 'CAGR (%)': np.float64(0.48), 'Volatility (%)': np.float64(1.31), 'Sharpe Ratio': np.float64(0.369), 'Total Trades': 589}
# [PNL] win=13, entry=1.376, exit=0.310 -> pnl=3,902,757
# | 8         | 3902756.7 | 12.672162 | 1.3764339 | 0.3099085 |
# {'Final Equity': np.float64(107973594.12802242), 'Net P/L': np.float64(7973594.128022417), 'Total Return (%)': np.float64(7.97), 'CAGR (%)': np.float64(0.97), 'Volatility (%)': np.float64(1.54), 'Sharpe Ratio': np.float64(0.63), 'Total Trades': 42}
# [PNL] win=30, entry=2.856, exit=0.260 -> pnl=7,973,594
# | 9         | 7973594.1 | 30.083849 | 2.8555278 | 0.2599021 |
# {'Final Equity': np.float64(111546061.84719047), 'Net P/L': np.float64(11546061.84719047), 'Total Return (%)': np.float64(11.55), 'CAGR (%)': np.float64(1.39), 'Volatility (%)': np.float64(2.56), 'Sharpe Ratio': np.float64(0.543), 'Total Trades': 143}
# [PNL] win=33, entry=2.277, exit=0.214 -> pnl=11,546,062
# | 10        | 1.154e+07 | 33.282894 | 2.2772437 | 0.2139351 |
# {'Final Equity': np.float64(99974696.07612306), 'Net P/L': np.float64(-25303.923876941204), 'Total Return (%)': np.float64(-0.03), 'CAGR (%)': np.float64(-0.0), 'Volatility (%)': np.float64(0.03), 'Sharpe Ratio': np.float64(-0.107), 'Total Trades': 4}
# [PNL] win=46, entry=3.500, exit=0.200 -> pnl=-25,304
# | 11        | -25303.92 | 46.344373 | 3.5       | 0.2       |
# {'Final Equity': np.float64(125707285.06030564), 'Net P/L': np.float64(25707285.06030564), 'Total Return (%)': np.float64(25.71), 'CAGR (%)': np.float64(2.93), 'Volatility (%)': np.float64(6.27), 'Sharpe Ratio': np.float64(0.467), 'Total Trades': 1638}
# [PNL] win=42, entry=0.500, exit=0.470 -> pnl=25,707,285
# | 12        | 2.570e+07 | 42.361718 | 0.5       | 0.4699883 |
# {'Final Equity': np.float64(102787806.0528789), 'Net P/L': np.float64(2787806.0528789014), 'Total Return (%)': np.float64(2.79), 'CAGR (%)': np.float64(0.35), 'Volatility (%)': np.float64(0.95), 'Sharpe Ratio': np.float64(0.366), 'Total Trades': 22}
# [PNL] win=41, entry=3.013, exit=0.500 -> pnl=2,787,806
# | 13        | 2787806.0 | 40.660337 | 3.0129360 | 0.5       |
# {'Final Equity': np.float64(148913966.54284292), 'Net P/L': np.float64(48913966.542842925), 'Total Return (%)': np.float64(48.91), 'CAGR (%)': np.float64(5.15), 'Volatility (%)': np.float64(7.85), 'Sharpe Ratio': np.float64(0.656), 'Total Trades': 1464}
# [PNL] win=41, entry=0.500, exit=0.200 -> pnl=48,913,967
# | 14        | 4.891e+07 | 40.688068 | 0.5       | 0.2       |
# {'Final Equity': np.float64(129828570.78467962), 'Net P/L': np.float64(29828570.78467962), 'Total Return (%)': np.float64(29.83), 'CAGR (%)': np.float64(3.35), 'Volatility (%)': np.float64(5.57), 'Sharpe Ratio': np.float64(0.602), 'Total Trades': 1649}
# [PNL] win=40, entry=0.500, exit=0.500 -> pnl=29,828,571
# | 15        | 2.982e+07 | 39.966239 | 0.5       | 0.5       |
# {'Final Equity': np.float64(123152268.28387399), 'Net P/L': np.float64(23152268.28387399), 'Total Return (%)': np.float64(23.15), 'CAGR (%)': np.float64(2.66), 'Volatility (%)': np.float64(5.75), 'Sharpe Ratio': np.float64(0.463), 'Total Trades': 1001}
# [PNL] win=41, entry=0.946, exit=0.200 -> pnl=23,152,268
# | 16        | 2.315e+07 | 41.116728 | 0.9458079 | 0.2       |
# {'Final Equity': np.float64(101868532.17132519), 'Net P/L': np.float64(1868532.1713251919), 'Total Return (%)': np.float64(1.87), 'CAGR (%)': np.float64(0.23), 'Volatility (%)': np.float64(0.51), 'Sharpe Ratio': np.float64(0.454), 'Total Trades': 17}
# [PNL] win=39, entry=3.071, exit=0.312 -> pnl=1,868,532
# | 17        | 1868532.1 | 39.288202 | 3.0714559 | 0.3117759 |
# {'Final Equity': np.float64(114615048.44680579), 'Net P/L': np.float64(14615048.44680579), 'Total Return (%)': np.float64(14.62), 'CAGR (%)': np.float64(1.74), 'Volatility (%)': np.float64(4.86), 'Sharpe Ratio': np.float64(0.358), 'Total Trades': 847}
# [PNL] win=36, entry=1.115, exit=0.229 -> pnl=14,615,048
# | 18        | 1.461e+07 | 36.191988 | 1.1153846 | 0.2285806 |
# {'Final Equity': np.float64(128190615.61336333), 'Net P/L': np.float64(28190615.613363326), 'Total Return (%)': np.float64(28.19), 'CAGR (%)': np.float64(3.18), 'Volatility (%)': np.float64(5.74), 'Sharpe Ratio': np.float64(0.555), 'Total Trades': 1649}
# [PNL] win=41, entry=0.500, exit=0.500 -> pnl=28,190,616
# | 19        | 2.819e+07 | 40.639439 | 0.5       | 0.5       |
# {'Final Equity': np.float64(140009160.61883587), 'Net P/L': np.float64(40009160.61883587), 'Total Return (%)': np.float64(40.01), 'CAGR (%)': np.float64(4.34), 'Volatility (%)': np.float64(7.25), 'Sharpe Ratio': np.float64(0.599), 'Total Trades': 1347}
# [PNL] win=40, entry=0.595, exit=0.200 -> pnl=40,009,161
# | 20        | 4.000e+07 | 40.458946 | 0.5949398 | 0.2       |
# {'Final Equity': np.float64(148913966.54284292), 'Net P/L': np.float64(48913966.542842925), 'Total Return (%)': np.float64(48.91), 'CAGR (%)': np.float64(5.15), 'Volatility (%)': np.float64(7.85), 'Sharpe Ratio': np.float64(0.656), 'Total Trades': 1464}
# [PNL] win=41, entry=0.500, exit=0.200 -> pnl=48,913,967
# | 21        | 4.891e+07 | 40.958360 | 0.5       | 0.2       |
# {'Final Equity': np.float64(152646557.13353455), 'Net P/L': np.float64(52646557.13353455), 'Total Return (%)': np.float64(52.65), 'CAGR (%)': np.float64(5.48), 'Volatility (%)': np.float64(8.39), 'Sharpe Ratio': np.float64(0.653), 'Total Trades': 1473}
# [PNL] win=42, entry=0.500, exit=0.200 -> pnl=52,646,557
# | 22        | 5.264e+07 | 41.500203 | 0.5       | 0.2       |
# {'Final Equity': np.float64(124671184.2949892), 'Net P/L': np.float64(24671184.2949892), 'Total Return (%)': np.float64(24.67), 'CAGR (%)': np.float64(2.82), 'Volatility (%)': np.float64(6.23), 'Sharpe Ratio': np.float64(0.453), 'Total Trades': 1647}
# [PNL] win=42, entry=0.500, exit=0.500 -> pnl=24,671,184
# | 23        | 2.467e+07 | 41.614980 | 0.5       | 0.5       |
# {'Final Equity': np.float64(148913966.54284292), 'Net P/L': np.float64(48913966.542842925), 'Total Return (%)': np.float64(48.91), 'CAGR (%)': np.float64(5.15), 'Volatility (%)': np.float64(7.85), 'Sharpe Ratio': np.float64(0.656), 'Total Trades': 1464}
# [PNL] win=41, entry=0.500, exit=0.200 -> pnl=48,913,967
# | 24        | 4.891e+07 | 41.275914 | 0.5       | 0.2       |
# {'Final Equity': np.float64(106474120.13846205), 'Net P/L': np.float64(6474120.138462052), 'Total Return (%)': np.float64(6.47), 'CAGR (%)': np.float64(0.79), 'Volatility (%)': np.float64(1.46), 'Sharpe Ratio': np.float64(0.545), 'Total Trades': 215}
# [PNL] win=24, entry=2.087, exit=0.389 -> pnl=6,474,120
# | 25        | 6474120.1 | 23.550403 | 2.0868502 | 0.3887710 |
# {'Final Equity': np.float64(127722975.97359492), 'Net P/L': np.float64(27722975.97359492), 'Total Return (%)': np.float64(27.72), 'CAGR (%)': np.float64(3.14), 'Volatility (%)': np.float64(6.37), 'Sharpe Ratio': np.float64(0.492), 'Total Trades': 1121}
# [PNL] win=42, entry=0.811, exit=0.200 -> pnl=27,722,976
# | 26        | 2.772e+07 | 41.826601 | 0.8112837 | 0.2       |
# {'Final Equity': np.float64(115980114.00361924), 'Net P/L': np.float64(15980114.003619239), 'Total Return (%)': np.float64(15.98), 'CAGR (%)': np.float64(1.89), 'Volatility (%)': np.float64(4.91), 'Sharpe Ratio': np.float64(0.384), 'Total Trades': 858}
# [PNL] win=40, entry=1.085, exit=0.200 -> pnl=15,980,114
# | 27        | 1.598e+07 | 39.633398 | 1.0851380 | 0.2       |
# {'Final Equity': np.float64(126882234.72648756), 'Net P/L': np.float64(26882234.726487562), 'Total Return (%)': np.float64(26.88), 'CAGR (%)': np.float64(3.05), 'Volatility (%)': np.float64(8.21), 'Sharpe Ratio': np.float64(0.371), 'Total Trades': 1379}
# [PNL] win=60, entry=0.649, exit=0.357 -> pnl=26,882,235
# | 28        | 2.688e+07 | 59.651788 | 0.6491205 | 0.3571504 |
# {'Final Equity': np.float64(129213048.4831219), 'Net P/L': np.float64(29213048.4831219), 'Total Return (%)': np.float64(29.21), 'CAGR (%)': np.float64(3.29), 'Volatility (%)': np.float64(5.57), 'Sharpe Ratio': np.float64(0.59), 'Total Trades': 1616}
# [PNL] win=40, entry=0.518, exit=0.486 -> pnl=29,213,048
# | 29        | 2.921e+07 | 39.966203 | 0.5182826 | 0.4861601 |
# {'Final Equity': np.float64(131937392.34521765), 'Net P/L': np.float64(31937392.345217645), 'Total Return (%)': np.float64(31.94), 'CAGR (%)': np.float64(3.56), 'Volatility (%)': np.float64(8.22), 'Sharpe Ratio': np.float64(0.433), 'Total Trades': 493}
# [PNL] win=60, entry=1.544, exit=0.288 -> pnl=31,937,392
# | 30        | 3.193e+07 | 59.512915 | 1.5443024 | 0.2884663 |
# {'Final Equity': np.float64(115366704.72271474), 'Net P/L': np.float64(15366704.722714737), 'Total Return (%)': np.float64(15.37), 'CAGR (%)': np.float64(1.82), 'Volatility (%)': np.float64(6.58), 'Sharpe Ratio': np.float64(0.277), 'Total Trades': 818}
# [PNL] win=59, entry=1.172, exit=0.310 -> pnl=15,366,705
# | 31        | 1.536e+07 | 58.881183 | 1.1722493 | 0.3101420 |
# {'Final Equity': np.float64(123297076.02739938), 'Net P/L': np.float64(23297076.027399376), 'Total Return (%)': np.float64(23.3), 'CAGR (%)': np.float64(2.68), 'Volatility (%)': np.float64(7.63), 'Sharpe Ratio': np.float64(0.351), 'Total Trades': 243}
# [PNL] win=60, entry=1.949, exit=0.500 -> pnl=23,297,076
# | 32        | 2.329e+07 | 60.0      | 1.9491498 | 0.5       |
# {'Final Equity': np.float64(144661864.08260953), 'Net P/L': np.float64(44661864.082609534), 'Total Return (%)': np.float64(44.66), 'CAGR (%)': np.float64(4.77), 'Volatility (%)': np.float64(11.38), 'Sharpe Ratio': np.float64(0.419), 'Total Trades': 726}
# [PNL] win=60, entry=1.212, exit=0.200 -> pnl=44,661,864
# | 33        | 4.466e+07 | 60.0      | 1.2123659 | 0.2       |
# {'Final Equity': np.float64(118933159.25016727), 'Net P/L': np.float64(18933159.250167266), 'Total Return (%)': np.float64(18.93), 'CAGR (%)': np.float64(2.21), 'Volatility (%)': np.float64(7.91), 'Sharpe Ratio': np.float64(0.28), 'Total Trades': 889}
# [PNL] win=60, entry=1.134, exit=0.500 -> pnl=18,933,159
# | 34        | 1.893e+07 | 60.0      | 1.1340558 | 0.5       |
# {'Final Equity': np.float64(102469411.73232825), 'Net P/L': np.float64(2469411.732328251), 'Total Return (%)': np.float64(2.47), 'CAGR (%)': np.float64(0.31), 'Volatility (%)': np.float64(0.97), 'Sharpe Ratio': np.float64(0.319), 'Total Trades': 669}
# [PNL] win=8, entry=1.295, exit=0.301 -> pnl=2,469,412
# | 35        | 2469411.7 | 8.2745041 | 1.2949077 | 0.3011745 |
# {'Final Equity': np.float64(131425366.36504199), 'Net P/L': np.float64(31425366.365041986), 'Total Return (%)': np.float64(31.43), 'CAGR (%)': np.float64(3.51), 'Volatility (%)': np.float64(7.41), 'Sharpe Ratio': np.float64(0.474), 'Total Trades': 1080}
# [PNL] win=50, entry=0.866, exit=0.245 -> pnl=31,425,366
# | 36        | 3.142e+07 | 49.697484 | 0.8664562 | 0.2452338 |
# {'Final Equity': np.float64(135321232.1943012), 'Net P/L': np.float64(35321232.19430119), 'Total Return (%)': np.float64(35.32), 'CAGR (%)': np.float64(3.89), 'Volatility (%)': np.float64(7.09), 'Sharpe Ratio': np.float64(0.548), 'Total Trades': 1261}
# [PNL] win=49, entry=0.716, exit=0.240 -> pnl=35,321,232
# | 37        | 3.532e+07 | 49.093124 | 0.7159129 | 0.2403007 |
# {'Final Equity': np.float64(106855140.55123557), 'Net P/L': np.float64(6855140.5512355715), 'Total Return (%)': np.float64(6.86), 'CAGR (%)': np.float64(0.84), 'Volatility (%)': np.float64(4.01), 'Sharpe Ratio': np.float64(0.209), 'Total Trades': 695}
# [PNL] win=49, entry=1.266, exit=0.244 -> pnl=6,855,141
# | 38        | 6855140.5 | 49.179455 | 1.2657689 | 0.2444025 |
# {'Final Equity': np.float64(101507364.83706836), 'Net P/L': np.float64(1507364.837068364), 'Total Return (%)': np.float64(1.51), 'CAGR (%)': np.float64(0.19), 'Volatility (%)': np.float64(0.19), 'Sharpe Ratio': np.float64(1.002), 'Total Trades': 16}
# [PNL] win=30, entry=3.170, exit=0.235 -> pnl=1,507,365
# | 39        | 1507364.8 | 29.876501 | 3.1702792 | 0.2345390 |
# {'Final Equity': np.float64(139266736.39488193), 'Net P/L': np.float64(39266736.394881934), 'Total Return (%)': np.float64(39.27), 'CAGR (%)': np.float64(4.27), 'Volatility (%)': np.float64(9.44), 'Sharpe Ratio': np.float64(0.452), 'Total Trades': 483}
# [PNL] win=60, entry=1.531, exit=0.200 -> pnl=39,266,736
# | 40        | 3.926e+07 | 60.0      | 1.5307041 | 0.2       |
# {'Final Equity': np.float64(120611983.11463302), 'Net P/L': np.float64(20611983.114633024), 'Total Return (%)': np.float64(20.61), 'CAGR (%)': np.float64(2.39), 'Volatility (%)': np.float64(7.0), 'Sharpe Ratio': np.float64(0.342), 'Total Trades': 1617}
# [PNL] win=49, entry=0.500, exit=0.500 -> pnl=20,611,983
# | 41        | 2.061e+07 | 48.675054 | 0.5       | 0.5       |
# {'Final Equity': np.float64(120611983.11463302), 'Net P/L': np.float64(20611983.114633024), 'Total Return (%)': np.float64(20.61), 'CAGR (%)': np.float64(2.39), 'Volatility (%)': np.float64(7.0), 'Sharpe Ratio': np.float64(0.342), 'Total Trades': 1617}
# [PNL] win=49, entry=0.500, exit=0.500 -> pnl=20,611,983
# | 42        | 2.061e+07 | 49.451318 | 0.5       | 0.5       |
# {'Final Equity': np.float64(130452322.24614161), 'Net P/L': np.float64(30452322.246141613), 'Total Return (%)': np.float64(30.45), 'CAGR (%)': np.float64(3.41), 'Volatility (%)': np.float64(8.04), 'Sharpe Ratio': np.float64(0.424), 'Total Trades': 142}
# [PNL] win=59, entry=2.211, exit=0.200 -> pnl=30,452,322
# | 43        | 3.045e+07 | 59.281745 | 2.2113010 | 0.2       |
# {'Final Equity': np.float64(105128066.53216013), 'Net P/L': np.float64(5128066.532160133), 'Total Return (%)': np.float64(5.13), 'CAGR (%)': np.float64(0.63), 'Volatility (%)': np.float64(1.89), 'Sharpe Ratio': np.float64(0.334), 'Total Trades': 32}
# [PNL] win=59, entry=2.885, exit=0.200 -> pnl=5,128,067
# | 44        | 5128066.5 | 59.333719 | 2.8851076 | 0.2       |
# {'Final Equity': np.float64(141607121.05227935), 'Net P/L': np.float64(41607121.05227935), 'Total Return (%)': np.float64(41.61), 'CAGR (%)': np.float64(4.49), 'Volatility (%)': np.float64(10.94), 'Sharpe Ratio': np.float64(0.41), 'Total Trades': 763}
# [PNL] win=60, entry=1.173, exit=0.200 -> pnl=41,607,121
# | 45        | 4.160e+07 | 59.688169 | 1.1734424 | 0.2       |
# {'Final Equity': np.float64(138608309.37295222), 'Net P/L': np.float64(38608309.37295222), 'Total Return (%)': np.float64(38.61), 'CAGR (%)': np.float64(4.21), 'Volatility (%)': np.float64(9.58), 'Sharpe Ratio': np.float64(0.439), 'Total Trades': 176}
# [PNL] win=59, entry=2.113, exit=0.200 -> pnl=38,608,309
# | 46        | 3.860e+07 | 58.593048 | 2.1131376 | 0.2       |
# {'Final Equity': np.float64(122637991.2922089), 'Net P/L': np.float64(22637991.292208895), 'Total Return (%)': np.float64(22.64), 'CAGR (%)': np.float64(2.61), 'Volatility (%)': np.float64(6.82), 'Sharpe Ratio': np.float64(0.382), 'Total Trades': 137}
# [PNL] win=58, entry=2.245, exit=0.200 -> pnl=22,637,991
# | 47        | 2.263e+07 | 58.077692 | 2.2451851 | 0.2       |
# {'Final Equity': np.float64(121815414.02118552), 'Net P/L': np.float64(21815414.021185517), 'Total Return (%)': np.float64(21.82), 'CAGR (%)': np.float64(2.52), 'Volatility (%)': np.float64(7.41), 'Sharpe Ratio': np.float64(0.34), 'Total Trades': 228}
# [PNL] win=59, entry=1.989, exit=0.500 -> pnl=21,815,414
# | 48        | 2.181e+07 | 58.874181 | 1.9893124 | 0.5       |
# {'Final Equity': np.float64(114642907.63565345), 'Net P/L': np.float64(14642907.635653451), 'Total Return (%)': np.float64(14.64), 'CAGR (%)': np.float64(1.74), 'Volatility (%)': np.float64(3.7), 'Sharpe Ratio': np.float64(0.47), 'Total Trades': 72}
# [PNL] win=59, entry=2.526, exit=0.200 -> pnl=14,642,908
# | 49        | 1.464e+07 | 58.612691 | 2.5255222 | 0.2       |
# {'Final Equity': np.float64(148913966.54284292), 'Net P/L': np.float64(48913966.542842925), 'Total Return (%)': np.float64(48.91), 'CAGR (%)': np.float64(5.15), 'Volatility (%)': np.float64(7.85), 'Sharpe Ratio': np.float64(0.656), 'Total Trades': 1464}
# [PNL] win=41, entry=0.500, exit=0.202 -> pnl=48,913,967
# | 50        | 4.891e+07 | 40.685634 | 0.5000114 | 0.2019355 |
# {'Final Equity': np.float64(107813969.32819813), 'Net P/L': np.float64(7813969.328198135), 'Total Return (%)': np.float64(7.81), 'CAGR (%)': np.float64(0.95), 'Volatility (%)': np.float64(3.62), 'Sharpe Ratio': np.float64(0.264), 'Total Trades': 331}
# [PNL] win=58, entry=1.747, exit=0.200 -> pnl=7,813,969
# | 51        | 7813969.3 | 58.377103 | 1.7470293 | 0.2       |
# {'Final Equity': np.float64(135379086.66168755), 'Net P/L': np.float64(35379086.66168755), 'Total Return (%)': np.float64(35.38), 'CAGR (%)': np.float64(3.9), 'Volatility (%)': np.float64(7.06), 'Sharpe Ratio': np.float64(0.552), 'Total Trades': 1271}
# [PNL] win=41, entry=0.675, exit=0.200 -> pnl=35,379,087
# | 52        | 3.537e+07 | 41.448536 | 0.6751856 | 0.2       |
# {'Final Equity': np.float64(127625041.31643371), 'Net P/L': np.float64(27625041.316433713), 'Total Return (%)': np.float64(27.63), 'CAGR (%)': np.float64(3.13), 'Volatility (%)': np.float64(5.9), 'Sharpe Ratio': np.float64(0.53), 'Total Trades': 1629}
# [PNL] win=41, entry=0.500, exit=0.435 -> pnl=27,625,041
# | 53        | 2.762e+07 | 41.099631 | 0.5       | 0.4350007 |
# {'Final Equity': np.float64(130914962.53082436), 'Net P/L': np.float64(30914962.530824363), 'Total Return (%)': np.float64(30.91), 'CAGR (%)': np.float64(3.46), 'Volatility (%)': np.float64(6.93), 'Sharpe Ratio': np.float64(0.499), 'Total Trades': 1193}
# [PNL] win=41, entry=0.739, exit=0.200 -> pnl=30,914,963
# | 54        | 3.091e+07 | 40.732928 | 0.7393704 | 0.2       |
# {'Final Equity': np.float64(168872348.1925248), 'Net P/L': np.float64(68872348.19252479), 'Total Return (%)': np.float64(68.87), 'CAGR (%)': np.float64(6.84), 'Volatility (%)': np.float64(9.39), 'Sharpe Ratio': np.float64(0.728), 'Total Trades': 1409}
# [PNL] win=50, entry=0.558, exit=0.200 -> pnl=68,872,348
# | 55        | 6.887e+07 | 50.150888 | 0.5578514 | 0.2       |
# {'Final Equity': np.float64(128749522.53674023), 'Net P/L': np.float64(28749522.53674023), 'Total Return (%)': np.float64(28.75), 'CAGR (%)': np.float64(3.24), 'Volatility (%)': np.float64(7.77), 'Sharpe Ratio': np.float64(0.417), 'Total Trades': 1563}
# [PNL] win=50, entry=0.500, exit=0.361 -> pnl=28,749,523
# | 56        | 2.874e+07 | 50.297843 | 0.5       | 0.3610831 |
# {'Final Equity': np.float64(168160582.4476), 'Net P/L': np.float64(68160582.4476), 'Total Return (%)': np.float64(68.16), 'CAGR (%)': np.float64(6.78), 'Volatility (%)': np.float64(9.34), 'Sharpe Ratio': np.float64(0.726), 'Total Trades': 1409}
# [PNL] win=50, entry=0.561, exit=0.200 -> pnl=68,160,582
# | 57        | 6.816e+07 | 49.987502 | 0.5609466 | 0.2       |
# {'Final Equity': np.float64(149181335.1782173), 'Net P/L': np.float64(49181335.17821729), 'Total Return (%)': np.float64(49.18), 'CAGR (%)': np.float64(5.18), 'Volatility (%)': np.float64(8.89), 'Sharpe Ratio': np.float64(0.582), 'Total Trades': 1204}
# [PNL] win=50, entry=0.735, exit=0.200 -> pnl=49,181,335
# | 58        | 4.918e+07 | 50.093350 | 0.7346761 | 0.2       |
# {'Final Equity': np.float64(174360557.78866437), 'Net P/L': np.float64(74360557.78866437), 'Total Return (%)': np.float64(74.36), 'CAGR (%)': np.float64(7.27), 'Volatility (%)': np.float64(10.06), 'Sharpe Ratio': np.float64(0.722), 'Total Trades': 1464}
# [PNL] win=50, entry=0.500, exit=0.200 -> pnl=74,360,558
# | 59        | 7.436e+07 | 50.068907 | 0.5       | 0.2       |
# {'Final Equity': np.float64(138516785.11762312), 'Net P/L': np.float64(38516785.11762312), 'Total Return (%)': np.float64(38.52), 'CAGR (%)': np.float64(4.2), 'Volatility (%)': np.float64(8.24), 'Sharpe Ratio': np.float64(0.509), 'Total Trades': 1531}
# [PNL] win=50, entry=0.500, exit=0.310 -> pnl=38,516,785
# | 60        | 3.851e+07 | 50.015781 | 0.5       | 0.3095178 |
# =============================================================

# %%
entry_z = opt.max['params']['entry_z']
exit_z  = opt.max['params']['exit_z']
window  = opt.max['params']['window']

# %%
df_bt, performance = backtest_pair_safe_fixed_shift(
    df_test,
    col1  = "BID.VN",
    col2  = "VCB.VN",
    beta_col    = "beta",
    zscore_col  = "zscore",
    entry_z = entry_z,
    exit_z  = exit_z,
    max_risk_per_trade  = 0.01,  # 1% NAV mỗi bước
    initial_cash  = 100_000_000,
    allow_short = False
)
# Out:
# {'Final Equity': np.float64(103792989.86269526), 'Net P/L': np.float64(3792989.862695262), 'Total Return (%)': np.float64(3.79), 'CAGR (%)': np.float64(1.9), 'Volatility (%)': np.float64(3.98), 'Sharpe Ratio': np.float64(0.477), 'Total Trades': 388}

# %%
plt.figure(figsize=(14, 7))
plt.plot(df_bt.index, df_bt['equity'], label='Equity')

plt.title("Equity Curve")
plt.legend()

# %% [markdown]
# #4.So sánh với chỉ số VNINDEX

# %%
import pandas as pd

df_bench = pd.read_csv("VNI.csv")
df_bench.rename(columns={"Ngày":"Date","Lần cuối":"Close"}, inplace=True)

# Convert datetime
df_bench["Date"] = pd.to_datetime(df_bench["Date"], format="%d/%m/%Y")

# Sort theo ngày tăng dần (rất quan trọng!)
df_bench = df_bench.sort_values("Date").reset_index(drop=True)

# Đặt index là datetime
df_bench = df_bench.set_index("Date")

# Lấy ra series giá đóng cửa
df_bench
# Out:
#                Close        Mở       Cao      Thấp       KL % Thay đổi
# Date
# 2015-10-01    563.54    563.39    565.63    563.23   82.59K      0.16%
# 2015-10-02    562.31    563.33    565.01    561.73   81.80K     -0.22%
# 2015-10-05    570.00    564.58    570.00    563.95   98.66K      1.37%
# 2015-10-06    581.29    577.45    581.38    574.63  179.24K      1.98%
# 2015-10-07    579.57    583.97    587.30    579.57  146.23K     -0.30%
# ...              ...       ...       ...       ...      ...        ...
# 2025-09-25  1,666.09  1,657.46  1,668.21  1,654.47  914.94M      0.52%
# 2025-09-26  1,660.70  1,666.09  1,671.43  1,652.65  899.32M     -0.32%
# 2025-09-29  1,666.48  1,660.70  1,674.84  1,639.20  808.66M      0.35%
# 2025-09-30  1,661.70  1,666.48  1,676.80  1,645.97    1.05B     -0.29%
# 2025-10-01  1,665.05  1,661.70  1,671.07  1,655.85  666.00M      0.20%
#
# [2500 rows x 6 columns]

# %%
import pandas as pd
import numpy as np

def benchmark_stats(price_series):
    """
    price_series: pandas Series giá đóng cửa benchmark (index = datetime)
    """

    # --- 1. Tính daily return ---
    ret = price_series.pct_change().dropna()

    # --- 2. CAGR ---
    n_days = len(ret)
    total_return = price_series.iloc[-1] / price_series.iloc[0] - 1
    cagr = (1 + total_return) ** (252 / n_days) - 1

    # --- 3. Volatility ---
    volatility = ret.std() * np.sqrt(252)

    # --- 4. Sharpe ---
    sharpe = cagr / volatility if volatility != 0 else np.nan

    # Kết quả
    result = {
        "Total Return (%)": round(total_return * 100, 2),
        "CAGR (%)": round(cagr * 100, 2),
        "Volatility (%)": round(volatility * 100, 2),
        "Sharpe Ratio": round(sharpe, 3),
    }

    return result, ret, price_series

# %%
df_bench = pd.read_csv("VNI.csv")
df_bench.rename(columns={"Ngày":"Date","Lần cuối":"Close"}, inplace=True)
df_bench["Date"] = pd.to_datetime(df_bench["Date"], format="%d/%m/%Y")
df_bench.set_index("Date", inplace=True)
df_bench["Close"] = df_bench["Close"].astype(str).str.replace(",", "").astype(float)

# %%
stats, returns, prices = benchmark_stats(df_bench["Close"])
stats
# Out:
# {'Total Return (%)': np.float64(-66.15),
#  'CAGR (%)': np.float64(-10.35),
#  'Volatility (%)': np.float64(18.41),
#  'Sharpe Ratio': np.float64(-0.562)}
